# %% [markdown]
# # Титульный лист
# <a name = 'Титульный_лист'>

# %% [markdown]
# <font face="times new roman" size="3" color="black">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="black"> Отчет пo практической рабoте №12 </center>
# <center>по дисциплине </center>
# <center><b>«Вв![Screenshot_1.png](data:image/png;base64,...![Screenshot_1.png](data:image/png;base64,...))едение в информационные технологии»</b></center>
# <center>на тему</center>
# <center><b>«Системы контроля версий»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Выполнил: cтудeнт грyппы </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black">       БИК2306 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Шестопалов Данил Сергеевич</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Прoвepил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Аccиcтeнт кафедры ТиЗВ Кудряшов В. В. </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="black"> Мocква, 2023 г. </p>
#
#   <hr>

# %% [markdown]
# > ## Содержание
#
# <a name = 'c'>

# %% [markdown]
# [1. Постановка задач](#Постановка_задач)
#
# [2. Ход работы](#Ход_работы)
#
# [3. Результат выполнения работы](#м)
#
# [4. Контрольное задание на защиту](#b)

# %% [markdown]
# # Постановка задач
# <a name = 'Постановка_задач'>

# %% [markdown]
# > ## Задание

# %% [markdown]
# 1. Установить GIT.
#
# 2. Создать локальный репозиторий.
#
# 3. Создать файл отчета по выполнению практической работы и поместить его в репозиторий
#
# 4. Зафиксируйте в отчете все проделанные шаги и создайте версию отчета в GIT
#
# 5. Создайте ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.
#
# 6. Слейте последнее изменение отчета в основную ветку.
#
# 7. Регистрируемся на github (или используем уже существующий аккаунт), создаем проект «homework IIT», залете содержимое из локального репозитория в проект на githab.
#
# 8. Разместить на github ранее созданный статический сайт.
#
# Доп. задание – Разметить на github ранее созданный динамический сайт.
#
# 9. Завершить отчет, добавив описание всех пунктов.

# %% [markdown]
# > ## Цель работы

# %% [markdown]
# Хостинг сайта с помощью GIT

# %% [markdown]
# > ## Задачи работы

# %% [markdown]
# 1. Установить GIT.
#
# 2. Создать локальный репозиторий.
#
# 3. Создать файл отчета по выполнению практической работы и поместить его в репозиторий
#
# 4. Зафиксировать в отчете все проделанные шаги и создать версию отчета в GIT
#
# 5. Создать ветку отчета в GIT, добавить описания шагов в отчет и создать версию отчета в новой ветке.
#
# 6. Залить последнее изменение отчета в основную ветку.
#
# 7. Зарегистрироваться на github (или использовать уже существующий аккаунт), создать проект «homework IIT», залить содержимое из локального репозитория в проект на githab.
#
# 8. Разместить на github ранее созданный статический сайт.
#
# 9. Завершить отчет, добавив описание всех пунктов.

# %% [markdown]
# > ## Расчет входных данных

# %% [markdown]
# Включить ноутбук, подключиться к интернет-сети.
# Открыть браузер.

# %% [markdown]
# #Ход работы
# <a name = 'Ход_работы'>

# %% [markdown]
# 1. Захожу на официальный сайт и скачиваю GIT для Windows.

# %% [markdown]
# 2. Создаю локальный репозиторий с помощью команды "git init" (рис.1)
#
# <center><img src="https://i.ibb.co/PYJsvHK/Screenshot-1.png" alt="Screenshot-1" border="0">
# <main>рис.1</main>

# %% [markdown]
# 3. Создаю файл отчёта по выполнению практической работы в репозитории (рис.2)
# <center><img src="https://i.ibb.co/ySxpZVf/Screenshot-2.png" alt="Screenshot-2" border="0">
# <main>рис.2<main>

# %% [markdown]
# 4. Фиксирую в отчете все проделанные шаги и создаю версию отчета в GIT (рис.3, рис.4).
# <center><img src="https://lh3.google.com/u/0/d/1ZXtmPlSEP9ppxCzpbCI4lQPAM_AKRh1M=w811-h652-iv1" class="a-b-ta-Ua" alt="Отображается файл &quot;6.PNG&quot;" aria-hidden="true">
# <main>рис.3</main>
# <img src="https://lh3.google.com/u/0/d/1MwMJZtgcd67vDNrfhGslB26KCGRJqmK9=w811-h652-iv1" class="a-b-ta-Ua" alt="Отображается файл &quot;10.PNG&quot;" aria-hidden="true">
# <main>рис.4</main>

# %% [markdown]
# 5.Создать ветку отчета в GIT, добавить описания шагов в отчет и создать версию отчета в новой ветке (рис.5).
# <center><img src="https://lh3.google.com/u/0/d/1lrIeBW9SjlH72ilSQCf7tsIymb7kTWeq=w811-h652-iv1" class="a-b-ta-Ua" alt="Отображается файл &quot;5.PNG&quot;" aria-hidden="true">
# <main>рис.5</main>

# %% [markdown]
# 6. Заливаю последнее изменение отчёта в основную ветку (рис.6)
# <center><img src="https://lh3.google.com/u/0/d/1XafQcPChIbA71rvi28PtlWmaCQcWX_xm=w811-h652-iv1" class="a-b-ta-Ua" alt="Отображается файл &quot;7.PNG&quot;" aria-hidden="true">
# <main>рис.6</main>

# %% [markdown]
# 7. Регистрируюсь на github, создаю проект «homework IIT», заливаю содержимое из локального репозитория в проект на githab (рис.7).
# <center><img src="https://lh3.google.com/u/0/d/1-MfcjhUhU8LQTAGd09xHEPm82T6Hl579=w1872-h964-iv1" class="a-b-ta-Ua" alt="Отображается файл &quot;9.PNG&quot;" aria-hidden="true">
# <main>рис.7</main>

# %% [markdown]
# 8. Размещаю на github ранее созданный статический сайт (рис.8).
# <center><img src="https://lh3.google.com/u/0/d/1MwMJZtgcd67vDNrfhGslB26KCGRJqmK9=w1872-h964-iv1" class="a-b-ta-Ua" alt="Отображается файл &quot;10.PNG&quot;" aria-hidden="true">
# <main>рис.8</main>

# %% [markdown]
# 9. Завершаю отчет, добавляя описание всех пунктов (рис.9, рис.10).
# <center><img src="https://lh3.google.com/u/0/d/1S9JFqZlMU-DQj-Ftc1qHvOtYHlv-YJFI=w1872-h964-iv1" class="a-b-ta-Ua" alt="Отображается файл &quot;11.PNG&quot;" aria-hidden="true">
# <main>рис.9</main>
# <img src="https://lh3.google.com/u/0/d/1F7ddLVxgPY985XzPeYtjMD-cjMnIVeuW=w1872-h964-iv1" class="a-b-ta-Ua" alt="Отображается файл &quot;kc.PNG&quot;" aria-hidden="true">
# <main>рис.10</main>

# %% [markdown]
# # Результат выполнения работы
# <a name = 'м'>

# %% [markdown]
# При поиске в браузере alex5039.github.io открывается главная страница моего сайта про рок-н-ролл (как и должно быть, рис.11). Все ссылки работают, фото- аудио- и видеоэлементы отображаются корректно (рис. 12, рис.13, рис.14, 15). Аудио- и видеофайлы воспроизводятся без искажений.
# <center><a href="https://postimg.cc/wtFS2wwY" target="_blank"><img src="https://i.postimg.cc/cHN0sjYC/osnova.png" alt="osnova"/></a><main>рис.11</main>
# <a href="https://postimg.cc/LhGGxY35" target="_blank"><img src="https://i.postimg.cc/Prqhr1LW/fotos1.png" alt="fotos1"/></a>
# <main>рис.12</main>
# <a href="https://postimg.cc/vgNCFcRP" target="_blank"><img src="https://i.postimg.cc/SRS49Mgp/fotos2.png" alt="fotos2"/></a>
# <main>рис.13</main>
# <a href="https://postimg.cc/PNCBbzZ0" target="_blank"><img src="https://i.postimg.cc/SQdkhgKQ/Zvykis.png" alt="Zvykis"/></a>
# <main>рис.14</main>
# <a href="https://postimg.cc/6yRggWM0" target="_blank"><img src="https://i.postimg.cc/28XYq3vP/videos.png" alt="videos"/></a>
# <main>рис.15</main>

# %% [markdown]
# # Контрольное задание на защиту
# <a name = 'b'>
